# %%
import bz2
import mjlog2json
import riichi
import json

# %%
h = "..."

compressed = bytes.fromhex(h)
decompressed = bz2.decompress(compressed).decode()

mjai_fmt = mjlog2json.convert_xml_to_mjai(decompressed)

# %%
# print(mjai_fmt)
# print(type(mjai_fmt))
print(mjlog2json.convert_xml_to_tenhou(decompressed))
# Out:
# {"ver":2.3,"ref":"","log":[[[0,0,0],[25000,25000,25000,25000],[34],[],[13,21,22,24,31,33,37,39,44,45,45,46,46],[15,42,"45p4545",17,22,12,16,19,"c323133","4646p46",39,43,36,18,39,53,17,32,27,22],[44,60,24,60,15,39,60,60,37,21,60,60,60,60,60,60,60,60,60,12],[11,51,18,22,23,52,27,31,33,35,36,41,47],[47,23,"c242352",42,39,28,32,46,21,38,24,26,38,11,36,25,29,36,"c272526",44],[11,18,27,41,60,60,42,51,46,21,31,32,33,36,38,38,35,36,36,60],[14,16,16,23,23,25,28,31,33,35,37,38,45],[33,26,17,42,11,19,28,37,16,24,44,12,41,14,29,41,32,19],[28,45,31,60,14,60,16,28,17,16,16,33,37,38,35,37,60,41],[12,12,13,13,14,17,21,29,31,32,34,37,47],[15,38,41,47,34,45,35,26,21,26,11,18,27,28,42,24,44],[29,21,60,31,17,60,32,34,60,15,37,38,18,35,60,34,60],["流局",[1500,-1500,-1500,1500]]],[[0,1,0],[26500,23500,23500,26500],[12],[],[14,16,18,19,24,28,33,33,34,45,45,46,46],[16,21,11,"p464646","p454545",37,37,24,25,43,47,"c323334",27,31],[28,60,60,33,24,60,60,60,60,60,60,14,60,60],[17,18,23,25,27,27,29,29,37,41,42,43,4
# ...

# %%
loader = riichi.dataset.GameplayLoader(4, oracle=False)
data = loader.load_json_log("\n".join(map(json.dumps, json.loads(mjai_fmt))))

# %%
obs = {
    "obs": data[0].take_obs(),
    "invisible_obs": data[0].take_invisible_obs(),
    "actions": data[0].take_actions(),
    "take_masks": data[0].take_masks(),
    "at_kyoku": data[0].take_at_kyoku(),
    "dones": data[0].take_dones(),
    "at_turns": data[0].take_at_turns(),
    "shantens": data[0].take_shantens(),
    "player_id": data[0].take_player_id(),
}

# %%
# obs["obs"][0]
# obs["actions"][0]
obs["take_masks"][0]
# Out:
# array([False, False,  True, False,  True, False, False, False, False,
#         True,  True, False,  True, False, False, False, False, False,
#         True, False,  True, False, False, False,  True, False,  True,
#        False, False, False,  True,  True,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False])
